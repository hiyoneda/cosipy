# %% [markdown]
# # Handling Good Time Intervals

# %%
from astropy.time import Time
from cosipy.event_selection import GoodTimeInterval
# Out:
# 11:21:24 WARNING   The naima package is not available. Models that depend on it will not be         ]8;id=978934;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=787876;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/astromodels/functions/functions_1D/functions.py#48\48]8;;\
#                   available
#          WARNING   The GSL library or the pygsl wrapper cannot be loaded. Models that depend on it  ]8;id=429492;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/astromodels/functions/functions_1D/functions.py\functions.py]8;;\:]8;id=137800;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/astromodels/functions/functions_1D/functions.py#69\69]8;;\
#                   will not be available.
#          WARNING   The ebltable package is not available. Models that depend on it will not be     ]8;id=138902;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/astromodels/functions/functions_1D/absorption.py\absorption.py]8;;\:]8;id=293831;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/astromodels/functions/functions_1D/absorption.py#33\33]8;;\
#                   available
#          INFO      Starting 3ML!                                                                     ]8;id=840293;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=161418;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py#39\39]8;;\
#          WARNING   WARNINGs here are NOT errors                                                      ]8;id=470213;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=938986;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py#40\40]8;;\
#          WARNING   but are inform you about optional packages that can be installed                  ]8;id=967033;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=987897;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py#41\41]8;;\
#          WARNING    to disable these messages, turn off start_warning in your config file            ]8;id=59320;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=990598;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py#44\44]8;;\
# 11:21:24 WARNING   ROOT minimizer not available                                                ]8;id=322315;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=991747;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/minimizer/minimization.py#1345\1345]8;;\
#          WARNING   Multinest minimizer not available                                           ]8;id=294305;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=714595;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/minimizer/minimization.py#1357\1357]8;;\
#          WARNING   PyGMO is not available                                                      ]8;id=514329;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/minimizer/minimization.py\minimization.py]8;;\:]8;id=195505;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/minimizer/minimization.py#1369\1369]8;;\
#          WARNING   The cthreeML package is not installed. You will not be able to use plugins which  ]8;id=516122;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=125456;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py#94\94]8;;\
#                   require the C/C++ interface (currently HAWC)
#          WARNING   Could not import plugin HAWCLike.py. Do you have the relative instrument         ]8;id=523818;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=820499;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   Could not import plugin FermiLATLike.py. Do you have the relative instrument     ]8;id=985630;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=912228;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py#144\144]8;;\
#                   software installed and configured?
#          WARNING   No fermitools installed                                              ]8;id=688198;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py\lat_transient_builder.py]8;;\:]8;id=130182;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/utils/data_builders/fermi/lat_transient_builder.py#44\44]8;;\
# 11:21:25 WARNING   Env. variable OMP_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=878952;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=750577;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable MKL_NUM_THREADS is not set. Please set it to 1 for optimal         ]8;id=997542;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=988386;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML
#          WARNING   Env. variable NUMEXPR_NUM_THREADS is not set. Please set it to 1 for optimal     ]8;id=741049;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py\__init__.py]8;;\:]8;id=418162;file:///Users/yoneda/Work/Exp/COSI/cosipy-2/cosipy-venv/cosipy-venv-20241022/lib/python3.10/site-packages/threeML/__init__.py#387\387]8;;\
#                   performances in 3ML

# %% [markdown]
# ## Instantiation
#
# Here, a good time interval (GTI) instance for the periods from 2025-10-22 to 2025-10-27 and from 2025-11-01 to 2025-11-06 is generated.

# %%
tstarts = Time([60970.0, 60980.0], format='mjd', scale = 'utc')
tstops  = Time([60975.0, 60985.0], format='mjd', scale = 'utc')

tstarts.iso, tstops.iso
# Out:
# (array(['2025-10-22 00:00:00.000', '2025-11-01 00:00:00.000'], dtype='<U23'),
#  array(['2025-10-27 00:00:00.000', '2025-11-06 00:00:00.000'], dtype='<U23'))

# %%
gti = GoodTimeInterval(tstarts, tstops)

# %%
n_range = len(gti)

for i, (tstart, tstop) in enumerate(gti):
    print(tstart.iso, '-', tstop.iso)
# Out:
# 2025-10-22 00:00:00.000 - 2025-10-27 00:00:00.000
# 2025-11-01 00:00:00.000 - 2025-11-06 00:00:00.000

# %% [markdown]
# ## Save GTI as a fits file

# %%
gti.save_as_fits('gti.fits')
# Out:
# WARNING: VerifyWarning: Keyword name 'TIMEFORMAT' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]

# %%
# open the save fits file
gti_from_fits = GoodTimeInterval.from_fits('gti.fits')

# %% [markdown]
# ## Calculate the intersection of several GTIs
#
# Considering that we have several GTIs, for instance, GTI from the SAA cut and GTI where a source is in the FoV of COSI, etc., we can calculate the final GTI as an intersection of these GTIs as follows.

# %%
#GTI1
tstarts_1 = Time([60970.0, 60980.0], format='mjd', scale = 'utc')
tstops_1  = Time([60975.0, 60985.0], format='mjd', scale = 'utc')

gti1 = GoodTimeInterval(tstarts_1, tstops_1)

#GTI2
tstarts_2 = Time([60972.0, 60979.0], format='mjd', scale = 'utc')
tstops_2  = Time([60977.0, 60983.0], format='mjd', scale = 'utc')

gti2 = GoodTimeInterval(tstarts_2, tstops_2)

#GTI3
tstarts_3 = Time([60970.0], format='mjd', scale = 'utc')
tstops_3  = Time([60990.0], format='mjd', scale = 'utc')

gti3 = GoodTimeInterval(tstarts_3, tstops_3)

# %%
for i, _gti in enumerate([gti1, gti2, gti3]):

    n_range = len(_gti)

    for (tstart, tstop) in _gti:
        print(f'GTI {i}: ', tstart.iso, '-', tstop.iso)
    
    print()
# Out:
# GTI 0:  2025-10-22 00:00:00.000 - 2025-10-27 00:00:00.000
# GTI 0:  2025-11-01 00:00:00.000 - 2025-11-06 00:00:00.000
#
# GTI 1:  2025-10-24 00:00:00.000 - 2025-10-29 00:00:00.000
# GTI 1:  2025-10-31 00:00:00.000 - 2025-11-04 00:00:00.000
#
# GTI 2:  2025-10-22 00:00:00.000 - 2025-11-11 00:00:00.000

# %%
# intersection

gti_intersection = GoodTimeInterval.intersection(gti1, gti2, gti3)

# %%
n_range = len(gti_intersection)

for i, (tstart, tstop) in enumerate(gti_intersection):
    print(f'GTI {i+1}/{n_range}: ', tstart.iso, '-', tstop.iso)
# Out:
# GTI 1/2:  2025-10-24 00:00:00.000 - 2025-10-27 00:00:00.000
# GTI 2/2:  2025-11-01 00:00:00.000 - 2025-11-04 00:00:00.000
